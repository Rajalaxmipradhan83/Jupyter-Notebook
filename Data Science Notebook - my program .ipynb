# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rajalaxmi Pradhan**
# Aspiring Data Scientist

# %% [markdown]
# *I am interested in data science because it offers endless possibilities to derive meaningful insights from data. I believe it can help solve complex problems and make a significant impact in various industries.*

# %% [markdown]
# ### Simple Code to Add Two Numbers
# This code performs a basic addition of two numbers to demonstrate how Jupyter cells execute Python code.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ### Additional Information:
#
# - **Reasons to Learn Data Science:**
#   - High demand in the job market
#   - Solves real-world problems
#   - Great salary potential
#
# 1. **Steps to Get Started:**
#    1. Learn Python and SQL.
#    2. Understand data manipulation.
#    3. Master machine learning.
#
# **Useful Resources:**
# - [IBM Watson Studio](https://www.ibm.com/cloud/watson-studio)
# - [Kaggle](https://www.kaggle.com)
#
# | Tool            | Purpose                   |
# |-----------------|---------------------------|
# | Python           | Data analysis, ML         |
# | SQL              | Data querying             |
# | Jupyter Notebook | Interactive coding        |
#
# ![Data Science Image](https://upload.wikimedia.org/wikipedia/commons/1/10/Python_logo_notext.svg)
